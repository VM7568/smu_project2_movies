# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import requests
import matplotlib.pyplot as plt
from config import key

# %%
# Create a browser for web scrapping.

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.58M/6.58M [00:01<00:00, 3.60MB/s]

# %%
# Use browser to visit the iMDB Top 250 web page.

url = 'https://www.imdb.com/chart/top?sort=ir,desc&mode=simple&page=1'
browser.visit(url)

# %%
# Soupify the web page.

html = browser.html
imdb = BeautifulSoup(html)
type(imdb)
# Out:
# bs4.BeautifulSoup

# %%
# Find the table list of top 250 movies.

top_movies = imdb.find("table", {"data-caller-name":"chart-top250movie"}).find("tbody").find_all("tr")
len(top_movies)
# Out:
# 250

# %%
# Test scrape to find the Movie ID for the first movie in the Top 250 list.

test = top_movies[0]
movie_id1 = test.find("td", {"class": "watchlistColumn"}).find("div")["data-tconst"]
movie_id1
# Out:
# 'tt0111161'

# %%
# Web scrapping loop to extract movie titles and corresponding movie_id.

top_250_ids = []

for movie in top_movies:
    title = movie.find("td", {"class": "titleColumn"}).find("a").text
    movie_id = movie.find("td", {"class": "watchlistColumn"}).find("div")["data-tconst"]
    
    row = {}
    row["title"] = title
    row["movie_id"] = movie_id
    top_250_ids.append(row)
    
movie_ids_df = pd.DataFrame(top_250_ids)
movie_ids_df
# Out:
#                                  title   movie_id
# 0             The Shawshank Redemption  tt0111161
# 1                        The Godfather  tt0068646
# 2                      The Dark Knight  tt0468569
# 3                The Godfather Part II  tt0071562
# 4                         12 Angry Men  tt0050083
# ..                                 ...        ...
# 245  Everything Everywhere All at Once  tt6710474
# 246                     The Iron Giant  tt0129167
# 247                           The Help  tt1454029
# 248                            Aladdin  tt0103639
# 249                             Gandhi  tt0083987
#
# [250 rows x 2 columns]

# %%
browser.quit()

# %%
# Using the OMDB API to acquire movie metadata. Initial test with The Shawshank Redemption movie ID.

api_url = f"http://www.omdbapi.com/?apikey={key}&i=tt0111161"
response = requests.get(api_url)
response.json()
# Out:
# {'Title': 'The Shawshank Redemption',
#  'Year': '1994',
#  'Rated': 'R',
#  'Released': '14 Oct 1994',
#  'Runtime': '142 min',
#  'Genre': 'Drama',
#  'Director': 'Frank Darabont',
#  'Writer': 'Stephen King, Frank Darabont',
#  'Actors': 'Tim Robbins, Morgan Freeman, Bob Gunton',
#  'Plot': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#  'Language': 'English',
#  'Country': 'United States',
#  'Awards': 'Nominated for 7 Oscars. 21 wins & 43 nominations total',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '9.3/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#   {'Source': 'Metacritic', 'Value': '81/100'}],
#  'Metascore': '81',
#  'imdbRating': '9.3',
#  'imdbVotes': '2,662,343',
#  'imdbID': 'tt0111161',
#  'Type': 'movie',
#  'DVD': '21 Dec 1999',
#  'BoxOffice': '$28,767,189',
#  'Production': 'N/A',
#  'Website': 'N/A',
#  'Response': 'True'}

# %%
# Another API test to look at getting single attributes of an individual movie.

id_code = "tt0111161"
api_url = f"http://www.omdbapi.com/?apikey={key}&i={id_code}"
response = requests.get(api_url)
movie_title = response.json().get("Title")
year_released = response.json().get("Year")
rating = response.json().get("Rated")
genre = response.json().get("Genre")
imdbRating = response.json().get("imdbRating")
Metascore = response.json().get("Metascore")
release_date = response.json().get("Released")
country = response.json().get("Country")
language = response.json().get("Language")
director = response.json().get("Director")
actors = response.json().get("Actors")
imdbVotes = response.json().get("imdbVotes")
earnings = response.json().get("BoxOffice")
imdbID = response.json().get("imdbID")

print(movie_title)
print(year_released)
print(rating)
print(genre)
print(imdbRating)
print(Metascore)
print(release_date)
print(country)
print(language)
print(director)
print(actors)
print(imdbVotes)
print(earnings)
print(imdbID)
# Out:
# The Shawshank Redemption
# 1994
# R
# Drama
# 9.3
# 81
# 14 Oct 1994
# United States
# English
# Frank Darabont
# Tim Robbins, Morgan Freeman, Bob Gunton
# 2,662,343
# $28,767,189
# tt0111161

# %%
movie_id_list = movie_ids_df['movie_id'].tolist()
len(movie_id_list)
# Out:
# 250

# %%
# Loop to extract all the metadata attributes associated with all of the top 250 movies, and turn into dataframe. 

rows = []

for x in movie_id_list:
    api_url = f"http://www.omdbapi.com/?apikey={key}&i=" + x
    response = requests.get(api_url)
    data = response.json()
    
    rows.append(data)
    
final_df = pd.DataFrame(rows)
final_df
# Out:
#                                  Title  Year     Rated     Released  Runtime  \
# 0             The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1                        The Godfather  1972         R  24 Mar 1972  175 min
# 2                      The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 3                The Godfather Part II  1974         R  18 Dec 1974  202 min
# 4                         12 Angry Men  1957  Approved  10 Apr 1957   96 min
# ..                                 ...   ...       ...          ...      ...
# 245  Everything Everywhere All at Once  2022         R  25 Mar 2022  139 min
# 246                     The Iron Giant  1999        PG  06 Aug 1999   86 min
# 247                           The Help  2011     PG-13  10 Aug 2011  146 min
# 248                            Aladdin  1992         G  25 Nov 1992   90 min
# 249                             Gandhi  1982        PG  25 Feb 1983  191 min
#
#                             Genre                    Director  \
# 0                           Drama              Frank Darabont
# 1                    Crime, Drama        Francis Ford Coppola
# 2            Action, Crime, Drama           Christopher Nolan
# 3                    Crime, Drama        Francis Ford Coppola
# 4                    Crime, Drama                Sidney Lumet
# ..                            ...                         ...
# 245     Action, Adventure, Comedy  Dan Kwan, Daniel Scheinert
# 246  Animation, Action, Adventure                   Brad Bird
# 247                         Drama                 Tate Taylor
# 248  Animation, Adventure, Comedy   Ron Clements, John Musker
# 249              Biography, Drama        Richard Attenborough
#
#                                                 Writer  \
# 0                         Stephen King, Frank Darabont
# 1                     Mario Puzo, Francis Ford Coppola
# 2    Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                     Francis Ford Coppola, Mario Puzo
# 4                                        Reginald Rose
# ..                                                 ...
# 245                         Dan Kwan, Daniel Scheinert
# 246               Tim McCanlies, Brad Bird, Ted Hughes
# 247                      Tate Taylor, Kathryn Stockett
# 248             Ron Clements, John Musker, Ted Elliott
# 249                                        John Briley
#
#                                                 Actors  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton
# 1                 Marlon Brando, Al Pacino, James Caan
# 2          Christian Bale, Heath Ledger, Aaron Eckhart
# 3             Al Pacino, Robert De Niro, Robert Duvall
# 4              Henry Fonda, Lee J. Cobb, Martin Balsam
# ..                                                 ...
# 245     Michelle Yeoh, Stephanie Hsu, Jamie Lee Curtis
# 246  Eli Marienthal, Harry Connick Jr., Jennifer An...
# 247           Viola Davis, Emma Stone, Octavia Spencer
# 248        Scott Weinger, Robin Williams, Linda Larkin
# 249      Ben Kingsley, John Gielgud, Rohini Hattangadi
#
#                                                   Plot  ... Metascore  \
# 0    Two imprisoned men bond over a number of years...  ...        81
# 1    The aging patriarch of an organized crime dyna...  ...       100
# 2    When the menace known as the Joker wreaks havo...  ...        84
# 3    The early life and career of Vito Corleone in ...  ...        90
# 4    The jury in a New York City murder trial is fr...  ...        96
# ..                                                 ...  ...       ...
# 245  An aging Chinese immigrant is swept up in an i...  ...        81
# 246  A young boy befriends a giant robot from outer...  ...        85
# 247  An aspiring author during the civil rights mov...  ...        62
# 248  A kindhearted street urchin and a power-hungry...  ...        86
# 249  The life of the lawyer who became the famed le...  ...        79
#
#     imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 0          9.3  2,662,343  tt0111161  movie  21 Dec 1999   $28,767,189
# 1          9.2  1,847,150  tt0068646  movie  11 May 2004  $136,381,073
# 2          9.0  2,638,780  tt0468569  movie  09 Dec 2008  $534,987,076
# 3          9.0  1,265,087  tt0071562  movie  24 May 2005   $47,834,595
# 4          9.0    786,180  tt0050083  movie  04 Mar 2008           N/A
# ..         ...        ...        ...    ...          ...           ...
# 245        8.1    251,736  tt6710474  movie  07 Jun 2022   $70,008,593
# 246        8.1    198,212  tt0129167  movie  27 Sep 2005   $23,315,035
# 247        8.1    459,753  tt1454029  movie  06 Dec 2011  $169,708,112
# 248        8.0    420,013  tt0103639  movie  13 Oct 2015  $217,350,219
# 249        8.1    232,139  tt0083987  movie  20 Feb 2007   $52,767,889
#
#     Production Website Response
# 0          N/A     N/A     True
# 1          N/A     N/A     True
# 2          N/A     N/A     True
# 3          N/A     N/A     True
# 4          N/A     N/A     True
# ..         ...     ...      ...
# 245        N/A     N/A     True
# 246        N/A     N/A     True
# 247        N/A     N/A     True
# 248        N/A     N/A     True
# 249        N/A     N/A     True
#
# [250 rows x 25 columns]

# %%
pd.set_option('display.max_columns', None)
final_df
# Out:
#                                  Title  Year     Rated     Released  Runtime  \
# 0             The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1                        The Godfather  1972         R  24 Mar 1972  175 min
# 2                      The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 3                The Godfather Part II  1974         R  18 Dec 1974  202 min
# 4                         12 Angry Men  1957  Approved  10 Apr 1957   96 min
# ..                                 ...   ...       ...          ...      ...
# 245  Everything Everywhere All at Once  2022         R  25 Mar 2022  139 min
# 246                     The Iron Giant  1999        PG  06 Aug 1999   86 min
# 247                           The Help  2011     PG-13  10 Aug 2011  146 min
# 248                            Aladdin  1992         G  25 Nov 1992   90 min
# 249                             Gandhi  1982        PG  25 Feb 1983  191 min
#
#                             Genre                    Director  \
# 0                           Drama              Frank Darabont
# 1                    Crime, Drama        Francis Ford Coppola
# 2            Action, Crime, Drama           Christopher Nolan
# 3                    Crime, Drama        Francis Ford Coppola
# 4                    Crime, Drama                Sidney Lumet
# ..                            ...                         ...
# 245     Action, Adventure, Comedy  Dan Kwan, Daniel Scheinert
# 246  Animation, Action, Adventure                   Brad Bird
# 247                         Drama                 Tate Taylor
# 248  Animation, Adventure, Comedy   Ron Clements, John Musker
# 249              Biography, Drama        Richard Attenborough
#
#                                                 Writer  \
# 0                         Stephen King, Frank Darabont
# 1                     Mario Puzo, Francis Ford Coppola
# 2    Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                     Francis Ford Coppola, Mario Puzo
# 4                                        Reginald Rose
# ..                                                 ...
# 245                         Dan Kwan, Daniel Scheinert
# 246               Tim McCanlies, Brad Bird, Ted Hughes
# 247                      Tate Taylor, Kathryn Stockett
# 248             Ron Clements, John Musker, Ted Elliott
# 249                                        John Briley
#
#                                                 Actors  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton
# 1                 Marlon Brando, Al Pacino, James Caan
# 2          Christian Bale, Heath Ledger, Aaron Eckhart
# 3             Al Pacino, Robert De Niro, Robert Duvall
# 4              Henry Fonda, Lee J. Cobb, Martin Balsam
# ..                                                 ...
# 245     Michelle Yeoh, Stephanie Hsu, Jamie Lee Curtis
# 246  Eli Marienthal, Harry Connick Jr., Jennifer An...
# 247           Viola Davis, Emma Stone, Octavia Spencer
# 248        Scott Weinger, Robin Williams, Linda Larkin
# 249      Ben Kingsley, John Gielgud, Rohini Hattangadi
#
#                                                   Plot  \
# 0    Two imprisoned men bond over a number of years...
# 1    The aging patriarch of an organized crime dyna...
# 2    When the menace known as the Joker wreaks havo...
# 3    The early life and career of Vito Corleone in ...
# 4    The jury in a New York City murder trial is fr...
# ..                                                 ...
# 245  An aging Chinese immigrant is swept up in an i...
# 246  A young boy befriends a giant robot from outer...
# 247  An aspiring author during the civil rights mov...
# 248  A kindhearted street urchin and a power-hungry...
# 249  The life of the lawyer who became the famed le...
#
#                                        Language  \
# 0                                       English
# 1                       English, Italian, Latin
# 2                             English, Mandarin
# 3    English, Italian, Spanish, Latin, Sicilian
# 4                                       English
# ..                                          ...
# 245                English, Mandarin, Cantonese
# 246                                     English
# 247                                     English
# 248                                     English
# 249                              English, Hindi
#
#                                                Country  \
# 0                                        United States
# 1                                        United States
# 2                        United States, United Kingdom
# 3                                        United States
# 4                                        United States
# ..                                                 ...
# 245                                      United States
# 246                                      United States
# 247                               United States, India
# 248                                      United States
# 249  United Kingdom, India, United States, South Af...
#
#                                                 Awards  \
# 0    Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1         Won 3 Oscars. 32 wins & 30 nominations total
# 2       Won 2 Oscars. 160 wins & 163 nominations total
# 3         Won 6 Oscars. 17 wins & 21 nominations total
# 4    Nominated for 3 Oscars. 17 wins & 13 nominatio...
# ..                                                 ...
# 245                          54 wins & 121 nominations
# 246    Won 1 BAFTA Award20 wins & 18 nominations total
# 247       Won 1 Oscar. 79 wins & 121 nominations total
# 248       Won 2 Oscars. 34 wins & 22 nominations total
# 249       Won 8 Oscars. 35 wins & 21 nominations total
#
#                                                 Poster  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 245  https://m.media-amazon.com/images/M/MV5BYTdiOT...
# 246  https://m.media-amazon.com/images/M/MV5BYzBjZT...
# 247  https://m.media-amazon.com/images/M/MV5BMTM5OT...
# 248  https://m.media-amazon.com/images/M/MV5BY2Q2ND...
# 249  https://m.media-amazon.com/images/M/MV5BOGVmZG...
#
#                                                Ratings Metascore imdbRating  \
# 0    [{'Source': 'Internet Movie Database', 'Value'...        81        9.3
# 1    [{'Source': 'Internet Movie Database', 'Value'...       100        9.2
# 2    [{'Source': 'Internet Movie Database', 'Value'...        84        9.0
# 3    [{'Source': 'Internet Movie Database', 'Value'...        90        9.0
# 4    [{'Source': 'Internet Movie Database', 'Value'...        96        9.0
# ..                                                 ...       ...        ...
# 245  [{'Source': 'Internet Movie Database', 'Value'...        81        8.1
# 246  [{'Source': 'Internet Movie Database', 'Value'...        85        8.1
# 247  [{'Source': 'Internet Movie Database', 'Value'...        62        8.1
# 248  [{'Source': 'Internet Movie Database', 'Value'...        86        8.0
# 249  [{'Source': 'Internet Movie Database', 'Value'...        79        8.1
#
#      imdbVotes     imdbID   Type          DVD     BoxOffice Production  \
# 0    2,662,343  tt0111161  movie  21 Dec 1999   $28,767,189        N/A
# 1    1,847,150  tt0068646  movie  11 May 2004  $136,381,073        N/A
# 2    2,638,780  tt0468569  movie  09 Dec 2008  $534,987,076        N/A
# 3    1,265,087  tt0071562  movie  24 May 2005   $47,834,595        N/A
# 4      786,180  tt0050083  movie  04 Mar 2008           N/A        N/A
# ..         ...        ...    ...          ...           ...        ...
# 245    251,736  tt6710474  movie  07 Jun 2022   $70,008,593        N/A
# 246    198,212  tt0129167  movie  27 Sep 2005   $23,315,035        N/A
# 247    459,753  tt1454029  movie  06 Dec 2011  $169,708,112        N/A
# 248    420,013  tt0103639  movie  13 Oct 2015  $217,350,219        N/A
# 249    232,139  tt0083987  movie  20 Feb 2007   $52,767,889        N/A
#
#     Website Response
# 0       N/A     True
# 1       N/A     True
# 2       N/A     True
# 3       N/A     True
# 4       N/A     True
# ..      ...      ...
# 245     N/A     True
# 246     N/A     True
# 247     N/A     True
# 248     N/A     True
# 249     N/A     True
#
# [250 rows x 25 columns]

# %%
# Remove extraneous columns.

clean_df1 = final_df.drop(columns=['Plot', 'Poster', 'Type', 'DVD', 'Production', 'Website', 'Response'])
clean_df1.head()
# Out:
#                       Title  Year     Rated     Released  Runtime  \
# 0  The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1             The Godfather  1972         R  24 Mar 1972  175 min
# 2           The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 3     The Godfather Part II  1974         R  18 Dec 1974  202 min
# 4              12 Angry Men  1957  Approved  10 Apr 1957   96 min
#
#                   Genre              Director  \
# 0                 Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2  Action, Crime, Drama     Christopher Nolan
# 3          Crime, Drama  Francis Ford Coppola
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                         Actors  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton
# 1         Marlon Brando, Al Pacino, James Caan
# 2  Christian Bale, Heath Ledger, Aaron Eckhart
# 3     Al Pacino, Robert De Niro, Robert Duvall
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam
#
#                                      Language                        Country  \
# 0                                     English                  United States
# 1                     English, Italian, Latin                  United States
# 2                           English, Mandarin  United States, United Kingdom
# 3  English, Italian, Spanish, Latin, Sicilian                  United States
# 4                                     English                  United States
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1       Won 3 Oscars. 32 wins & 30 nominations total
# 2     Won 2 Oscars. 160 wins & 163 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...
#
#                                              Ratings Metascore imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...        81        9.3
# 1  [{'Source': 'Internet Movie Database', 'Value'...       100        9.2
# 2  [{'Source': 'Internet Movie Database', 'Value'...        84        9.0
# 3  [{'Source': 'Internet Movie Database', 'Value'...        90        9.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...        96        9.0
#
#    imdbVotes     imdbID     BoxOffice
# 0  2,662,343  tt0111161   $28,767,189
# 1  1,847,150  tt0068646  $136,381,073
# 2  2,638,780  tt0468569  $534,987,076
# 3  1,265,087  tt0071562   $47,834,595
# 4    786,180  tt0050083           N/A

# %%
clean_df1 = clean_df1.replace("N/A", 0)
clean_df1.head()
# Out:
#                       Title  Year     Rated     Released  Runtime  \
# 0  The Shawshank Redemption  1994         R  14 Oct 1994  142 min
# 1             The Godfather  1972         R  24 Mar 1972  175 min
# 2           The Dark Knight  2008     PG-13  18 Jul 2008  152 min
# 3     The Godfather Part II  1974         R  18 Dec 1974  202 min
# 4              12 Angry Men  1957  Approved  10 Apr 1957   96 min
#
#                   Genre              Director  \
# 0                 Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2  Action, Crime, Drama     Christopher Nolan
# 3          Crime, Drama  Francis Ford Coppola
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                         Actors  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton
# 1         Marlon Brando, Al Pacino, James Caan
# 2  Christian Bale, Heath Ledger, Aaron Eckhart
# 3     Al Pacino, Robert De Niro, Robert Duvall
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam
#
#                                      Language                        Country  \
# 0                                     English                  United States
# 1                     English, Italian, Latin                  United States
# 2                           English, Mandarin  United States, United Kingdom
# 3  English, Italian, Spanish, Latin, Sicilian                  United States
# 4                                     English                  United States
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1       Won 3 Oscars. 32 wins & 30 nominations total
# 2     Won 2 Oscars. 160 wins & 163 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...
#
#                                              Ratings Metascore imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...        81        9.3
# 1  [{'Source': 'Internet Movie Database', 'Value'...       100        9.2
# 2  [{'Source': 'Internet Movie Database', 'Value'...        84        9.0
# 3  [{'Source': 'Internet Movie Database', 'Value'...        90        9.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...        96        9.0
#
#    imdbVotes     imdbID     BoxOffice
# 0  2,662,343  tt0111161   $28,767,189
# 1  1,847,150  tt0068646  $136,381,073
# 2  2,638,780  tt0468569  $534,987,076
# 3  1,265,087  tt0071562   $47,834,595
# 4    786,180  tt0050083             0

# %%
# Convert data to proper types.

clean_df1['Year'] = clean_df1['Year'].astype(int)
clean_df1['Metascore'] = clean_df1['Metascore'].astype(float)
clean_df1['imdbRating'] = clean_df1['imdbRating'].astype(float)
clean_df1['imdbVotes'] = clean_df1['imdbVotes'].str.replace(",", "")
clean_df1['imdbVotes'] = clean_df1['imdbVotes'].astype(int)
clean_df1['Runtime'] = clean_df1['Runtime'].str.replace(" min", "")
clean_df1['Runtime'] = clean_df1['Runtime'].astype(int)

clean_df1.head()
# Out:
#                       Title  Year     Rated     Released  Runtime  \
# 0  The Shawshank Redemption  1994         R  14 Oct 1994      142
# 1             The Godfather  1972         R  24 Mar 1972      175
# 2           The Dark Knight  2008     PG-13  18 Jul 2008      152
# 3     The Godfather Part II  1974         R  18 Dec 1974      202
# 4              12 Angry Men  1957  Approved  10 Apr 1957       96
#
#                   Genre              Director  \
# 0                 Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2  Action, Crime, Drama     Christopher Nolan
# 3          Crime, Drama  Francis Ford Coppola
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                         Actors  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton
# 1         Marlon Brando, Al Pacino, James Caan
# 2  Christian Bale, Heath Ledger, Aaron Eckhart
# 3     Al Pacino, Robert De Niro, Robert Duvall
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam
#
#                                      Language                        Country  \
# 0                                     English                  United States
# 1                     English, Italian, Latin                  United States
# 2                           English, Mandarin  United States, United Kingdom
# 3  English, Italian, Spanish, Latin, Sicilian                  United States
# 4                                     English                  United States
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1       Won 3 Oscars. 32 wins & 30 nominations total
# 2     Won 2 Oscars. 160 wins & 163 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...
#
#                                              Ratings  Metascore  imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...       81.0         9.3
# 1  [{'Source': 'Internet Movie Database', 'Value'...      100.0         9.2
# 2  [{'Source': 'Internet Movie Database', 'Value'...       84.0         9.0
# 3  [{'Source': 'Internet Movie Database', 'Value'...       90.0         9.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...       96.0         9.0
#
#    imdbVotes     imdbID     BoxOffice
# 0    2662343  tt0111161   $28,767,189
# 1    1847150  tt0068646  $136,381,073
# 2    2638780  tt0468569  $534,987,076
# 3    1265087  tt0071562   $47,834,595
# 4     786180  tt0050083             0

# %%
# More data conversions.
clean_df1.rename(columns = {'Runtime':'Runtime_mins'}, inplace = True)
clean_df1.head()
# Out:
#                       Title  Year     Rated     Released  Runtime_mins  \
# 0  The Shawshank Redemption  1994         R  14 Oct 1994           142
# 1             The Godfather  1972         R  24 Mar 1972           175
# 2           The Dark Knight  2008     PG-13  18 Jul 2008           152
# 3     The Godfather Part II  1974         R  18 Dec 1974           202
# 4              12 Angry Men  1957  Approved  10 Apr 1957            96
#
#                   Genre              Director  \
# 0                 Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2  Action, Crime, Drama     Christopher Nolan
# 3          Crime, Drama  Francis Ford Coppola
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                         Actors  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton
# 1         Marlon Brando, Al Pacino, James Caan
# 2  Christian Bale, Heath Ledger, Aaron Eckhart
# 3     Al Pacino, Robert De Niro, Robert Duvall
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam
#
#                                      Language                        Country  \
# 0                                     English                  United States
# 1                     English, Italian, Latin                  United States
# 2                           English, Mandarin  United States, United Kingdom
# 3  English, Italian, Spanish, Latin, Sicilian                  United States
# 4                                     English                  United States
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1       Won 3 Oscars. 32 wins & 30 nominations total
# 2     Won 2 Oscars. 160 wins & 163 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...
#
#                                              Ratings  Metascore  imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...       81.0         9.3
# 1  [{'Source': 'Internet Movie Database', 'Value'...      100.0         9.2
# 2  [{'Source': 'Internet Movie Database', 'Value'...       84.0         9.0
# 3  [{'Source': 'Internet Movie Database', 'Value'...       90.0         9.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...       96.0         9.0
#
#    imdbVotes     imdbID     BoxOffice
# 0    2662343  tt0111161   $28,767,189
# 1    1847150  tt0068646  $136,381,073
# 2    2638780  tt0468569  $534,987,076
# 3    1265087  tt0071562   $47,834,595
# 4     786180  tt0050083             0

# %%
clean_df1.rename(columns = {'Actors':'Top_Billed'}, inplace = True)
clean_df1.head()
# Out:
#                       Title  Year     Rated     Released  Runtime_mins  \
# 0  The Shawshank Redemption  1994         R  14 Oct 1994           142
# 1             The Godfather  1972         R  24 Mar 1972           175
# 2           The Dark Knight  2008     PG-13  18 Jul 2008           152
# 3     The Godfather Part II  1974         R  18 Dec 1974           202
# 4              12 Angry Men  1957  Approved  10 Apr 1957            96
#
#                   Genre              Director  \
# 0                 Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2  Action, Crime, Drama     Christopher Nolan
# 3          Crime, Drama  Francis Ford Coppola
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                     Top_Billed  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton
# 1         Marlon Brando, Al Pacino, James Caan
# 2  Christian Bale, Heath Ledger, Aaron Eckhart
# 3     Al Pacino, Robert De Niro, Robert Duvall
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam
#
#                                      Language                        Country  \
# 0                                     English                  United States
# 1                     English, Italian, Latin                  United States
# 2                           English, Mandarin  United States, United Kingdom
# 3  English, Italian, Spanish, Latin, Sicilian                  United States
# 4                                     English                  United States
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1       Won 3 Oscars. 32 wins & 30 nominations total
# 2     Won 2 Oscars. 160 wins & 163 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...
#
#                                              Ratings  Metascore  imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...       81.0         9.3
# 1  [{'Source': 'Internet Movie Database', 'Value'...      100.0         9.2
# 2  [{'Source': 'Internet Movie Database', 'Value'...       84.0         9.0
# 3  [{'Source': 'Internet Movie Database', 'Value'...       90.0         9.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...       96.0         9.0
#
#    imdbVotes     imdbID     BoxOffice
# 0    2662343  tt0111161   $28,767,189
# 1    1847150  tt0068646  $136,381,073
# 2    2638780  tt0468569  $534,987,076
# 3    1265087  tt0071562   $47,834,595
# 4     786180  tt0050083             0

# %%
clean_df1['BoxOffice'] = clean_df1['BoxOffice'].str.replace("$", "")
clean_df1['BoxOffice'] = clean_df1['BoxOffice'].str.replace(",", "")
clean_df1['BoxOffice'] = clean_df1['BoxOffice'].astype(float)
clean_df1.head()
# Out:
# C:\Users\garre\AppData\Local\Temp\ipykernel_10408\3322882663.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   clean_df1['BoxOffice'] = clean_df1['BoxOffice'].str.replace("$", "")
#                       Title  Year     Rated     Released  Runtime_mins  \
# 0  The Shawshank Redemption  1994         R  14 Oct 1994           142
# 1             The Godfather  1972         R  24 Mar 1972           175
# 2           The Dark Knight  2008     PG-13  18 Jul 2008           152
# 3     The Godfather Part II  1974         R  18 Dec 1974           202
# 4              12 Angry Men  1957  Approved  10 Apr 1957            96
#
#                   Genre              Director  \
# 0                 Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2  Action, Crime, Drama     Christopher Nolan
# 3          Crime, Drama  Francis Ford Coppola
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                     Top_Billed  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton
# 1         Marlon Brando, Al Pacino, James Caan
# 2  Christian Bale, Heath Ledger, Aaron Eckhart
# 3     Al Pacino, Robert De Niro, Robert Duvall
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam
#
#                                      Language                        Country  \
# 0                                     English                  United States
# 1                     English, Italian, Latin                  United States
# 2                           English, Mandarin  United States, United Kingdom
# 3  English, Italian, Spanish, Latin, Sicilian                  United States
# 4                                     English                  United States
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1       Won 3 Oscars. 32 wins & 30 nominations total
# 2     Won 2 Oscars. 160 wins & 163 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...
#
#                                              Ratings  Metascore  imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...       81.0         9.3
# 1  [{'Source': 'Internet Movie Database', 'Value'...      100.0         9.2
# 2  [{'Source': 'Internet Movie Database', 'Value'...       84.0         9.0
# 3  [{'Source': 'Internet Movie Database', 'Value'...       90.0         9.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...       96.0         9.0
#
#    imdbVotes     imdbID    BoxOffice
# 0    2662343  tt0111161   28767189.0
# 1    1847150  tt0068646  136381073.0
# 2    2638780  tt0468569  534987076.0
# 3    1265087  tt0071562   47834595.0
# 4     786180  tt0050083          NaN

# %%
clean_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         250 non-null    object
#  1   Year          250 non-null    int32
#  2   Rated         250 non-null    object
#  3   Released      250 non-null    object
#  4   Runtime_mins  250 non-null    int32
#  5   Genre         250 non-null    object
#  6   Director      250 non-null    object
#  7   Writer        250 non-null    object
#  8   Top_Billed    250 non-null    object
#  9   Language      250 non-null    object
#  10  Country       250 non-null    object
#  11  Awards        250 non-null    object
#  12  Ratings       250 non-null    object
#  13  Metascore     250 non-null    float64
#  14  imdbRating    250 non-null    float64
#  15  imdbVotes     250 non-null    int32
#  16  imdbID        250 non-null    object
#  17  BoxOffice     220 non-null    float64
# dtypes: float64(3), int32(3), object(12)
# memory usage: 32.4+ KB

# %%
# Adding imdbRank as new column for the Top 250 IMDB movies.
clean_df1.insert(0, 'imdbRank', range(1, 1 + len(clean_df1)))
clean_df1
# Out:
#      imdbRank                              Title  Year     Rated     Released  \
# 0           1           The Shawshank Redemption  1994         R  14 Oct 1994
# 1           2                      The Godfather  1972         R  24 Mar 1972
# 2           3                    The Dark Knight  2008     PG-13  18 Jul 2008
# 3           4              The Godfather Part II  1974         R  18 Dec 1974
# 4           5                       12 Angry Men  1957  Approved  10 Apr 1957
# ..        ...                                ...   ...       ...          ...
# 245       246  Everything Everywhere All at Once  2022         R  25 Mar 2022
# 246       247                     The Iron Giant  1999        PG  06 Aug 1999
# 247       248                           The Help  2011     PG-13  10 Aug 2011
# 248       249                            Aladdin  1992         G  25 Nov 1992
# 249       250                             Gandhi  1982        PG  25 Feb 1983
#
#      Runtime_mins                         Genre                    Director  \
# 0             142                         Drama              Frank Darabont
# 1             175                  Crime, Drama        Francis Ford Coppola
# 2             152          Action, Crime, Drama           Christopher Nolan
# 3             202                  Crime, Drama        Francis Ford Coppola
# 4              96                  Crime, Drama                Sidney Lumet
# ..            ...                           ...                         ...
# 245           139     Action, Adventure, Comedy  Dan Kwan, Daniel Scheinert
# 246            86  Animation, Action, Adventure                   Brad Bird
# 247           146                         Drama                 Tate Taylor
# 248            90  Animation, Adventure, Comedy   Ron Clements, John Musker
# 249           191              Biography, Drama        Richard Attenborough
#
#                                                 Writer  \
# 0                         Stephen King, Frank Darabont
# 1                     Mario Puzo, Francis Ford Coppola
# 2    Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                     Francis Ford Coppola, Mario Puzo
# 4                                        Reginald Rose
# ..                                                 ...
# 245                         Dan Kwan, Daniel Scheinert
# 246               Tim McCanlies, Brad Bird, Ted Hughes
# 247                      Tate Taylor, Kathryn Stockett
# 248             Ron Clements, John Musker, Ted Elliott
# 249                                        John Briley
#
#                                             Top_Billed  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton
# 1                 Marlon Brando, Al Pacino, James Caan
# 2          Christian Bale, Heath Ledger, Aaron Eckhart
# 3             Al Pacino, Robert De Niro, Robert Duvall
# 4              Henry Fonda, Lee J. Cobb, Martin Balsam
# ..                                                 ...
# 245     Michelle Yeoh, Stephanie Hsu, Jamie Lee Curtis
# 246  Eli Marienthal, Harry Connick Jr., Jennifer An...
# 247           Viola Davis, Emma Stone, Octavia Spencer
# 248        Scott Weinger, Robin Williams, Linda Larkin
# 249      Ben Kingsley, John Gielgud, Rohini Hattangadi
#
#                                        Language  \
# 0                                       English
# 1                       English, Italian, Latin
# 2                             English, Mandarin
# 3    English, Italian, Spanish, Latin, Sicilian
# 4                                       English
# ..                                          ...
# 245                English, Mandarin, Cantonese
# 246                                     English
# 247                                     English
# 248                                     English
# 249                              English, Hindi
#
#                                                Country  \
# 0                                        United States
# 1                                        United States
# 2                        United States, United Kingdom
# 3                                        United States
# 4                                        United States
# ..                                                 ...
# 245                                      United States
# 246                                      United States
# 247                               United States, India
# 248                                      United States
# 249  United Kingdom, India, United States, South Af...
#
#                                                 Awards  \
# 0    Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1         Won 3 Oscars. 32 wins & 30 nominations total
# 2       Won 2 Oscars. 160 wins & 163 nominations total
# 3         Won 6 Oscars. 17 wins & 21 nominations total
# 4    Nominated for 3 Oscars. 17 wins & 13 nominatio...
# ..                                                 ...
# 245                          54 wins & 121 nominations
# 246    Won 1 BAFTA Award20 wins & 18 nominations total
# 247       Won 1 Oscar. 79 wins & 121 nominations total
# 248       Won 2 Oscars. 34 wins & 22 nominations total
# 249       Won 8 Oscars. 35 wins & 21 nominations total
#
#                                                Ratings  Metascore  imdbRating  \
# 0    [{'Source': 'Internet Movie Database', 'Value'...       81.0         9.3
# 1    [{'Source': 'Internet Movie Database', 'Value'...      100.0         9.2
# 2    [{'Source': 'Internet Movie Database', 'Value'...       84.0         9.0
# 3    [{'Source': 'Internet Movie Database', 'Value'...       90.0         9.0
# 4    [{'Source': 'Internet Movie Database', 'Value'...       96.0         9.0
# ..                                                 ...        ...         ...
# 245  [{'Source': 'Internet Movie Database', 'Value'...       81.0         8.1
# 246  [{'Source': 'Internet Movie Database', 'Value'...       85.0         8.1
# 247  [{'Source': 'Internet Movie Database', 'Value'...       62.0         8.1
# 248  [{'Source': 'Internet Movie Database', 'Value'...       86.0         8.0
# 249  [{'Source': 'Internet Movie Database', 'Value'...       79.0         8.1
#
#      imdbVotes     imdbID    BoxOffice
# 0      2662343  tt0111161   28767189.0
# 1      1847150  tt0068646  136381073.0
# 2      2638780  tt0468569  534987076.0
# 3      1265087  tt0071562   47834595.0
# 4       786180  tt0050083          NaN
# ..         ...        ...          ...
# 245     251736  tt6710474   70008593.0
# 246     198212  tt0129167   23315035.0
# 247     459753  tt1454029  169708112.0
# 248     420013  tt0103639  217350219.0
# 249     232139  tt0083987   52767889.0
#
# [250 rows x 19 columns]

# %%
# clean_df1.to_csv("IMDB_Cleaned_1.csv", encoding='utf-8', index=False)

# %%
clean_df1["Genre"] = clean_df1.Genre.apply(lambda x: x.split(",")[0])

# %%
clean_df1["Language"] = clean_df1.Language.apply(lambda x: x.split(",")[0])
clean_df1["Country"] = clean_df1.Country.apply(lambda x: x.split(",")[0])
clean_df1.head()
# Out:
#    imdbRank                     Title  Year     Rated     Released  \
# 0         1  The Shawshank Redemption  1994         R  14 Oct 1994
# 1         2             The Godfather  1972         R  24 Mar 1972
# 2         3           The Dark Knight  2008     PG-13  18 Jul 2008
# 3         4     The Godfather Part II  1974         R  18 Dec 1974
# 4         5              12 Angry Men  1957  Approved  10 Apr 1957
#
#    Runtime_mins   Genre              Director  \
# 0           142   Drama        Frank Darabont
# 1           175   Crime  Francis Ford Coppola
# 2           152  Action     Christopher Nolan
# 3           202   Crime  Francis Ford Coppola
# 4            96   Crime          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                     Top_Billed Language        Country  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton  English  United States
# 1         Marlon Brando, Al Pacino, James Caan  English  United States
# 2  Christian Bale, Heath Ledger, Aaron Eckhart  English  United States
# 3     Al Pacino, Robert De Niro, Robert Duvall  English  United States
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam  English  United States
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1       Won 3 Oscars. 32 wins & 30 nominations total
# 2     Won 2 Oscars. 160 wins & 163 nominations total
# 3       Won 6 Oscars. 17 wins & 21 nominations total
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...
#
#                                              Ratings  Metascore  imdbRating  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...       81.0         9.3
# 1  [{'Source': 'Internet Movie Database', 'Value'...      100.0         9.2
# 2  [{'Source': 'Internet Movie Database', 'Value'...       84.0         9.0
# 3  [{'Source': 'Internet Movie Database', 'Value'...       90.0         9.0
# 4  [{'Source': 'Internet Movie Database', 'Value'...       96.0         9.0
#
#    imdbVotes     imdbID    BoxOffice
# 0    2662343  tt0111161   28767189.0
# 1    1847150  tt0068646  136381073.0
# 2    2638780  tt0468569  534987076.0
# 3    1265087  tt0071562   47834595.0
# 4     786180  tt0050083          NaN

# %%
clean_df1.Rated.value_counts()
# Out:
# R            102
# PG            37
# PG-13         34
# Not Rated     24
# G             19
# Passed        16
# Approved      13
# TV-PG          1
# Unrated        1
# X              1
# TV-MA          1
# GP             1
# Name: Rated, dtype: int64

# %%
clean_df1 = clean_df1.drop(columns=['Ratings'])
clean_df1.head()
# Out:
#    imdbRank                     Title  Year     Rated     Released  \
# 0         1  The Shawshank Redemption  1994         R  14 Oct 1994
# 1         2             The Godfather  1972         R  24 Mar 1972
# 2         3           The Dark Knight  2008     PG-13  18 Jul 2008
# 3         4     The Godfather Part II  1974         R  18 Dec 1974
# 4         5              12 Angry Men  1957  Approved  10 Apr 1957
#
#    Runtime_mins   Genre              Director  \
# 0           142   Drama        Frank Darabont
# 1           175   Crime  Francis Ford Coppola
# 2           152  Action     Christopher Nolan
# 3           202   Crime  Francis Ford Coppola
# 4            96   Crime          Sidney Lumet
#
#                                               Writer  \
# 0                       Stephen King, Frank Darabont
# 1                   Mario Puzo, Francis Ford Coppola
# 2  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                   Francis Ford Coppola, Mario Puzo
# 4                                      Reginald Rose
#
#                                     Top_Billed Language        Country  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton  English  United States
# 1         Marlon Brando, Al Pacino, James Caan  English  United States
# 2  Christian Bale, Heath Ledger, Aaron Eckhart  English  United States
# 3     Al Pacino, Robert De Niro, Robert Duvall  English  United States
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam  English  United States
#
#                                               Awards  Metascore  imdbRating  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...       81.0         9.3
# 1       Won 3 Oscars. 32 wins & 30 nominations total      100.0         9.2
# 2     Won 2 Oscars. 160 wins & 163 nominations total       84.0         9.0
# 3       Won 6 Oscars. 17 wins & 21 nominations total       90.0         9.0
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...       96.0         9.0
#
#    imdbVotes     imdbID    BoxOffice
# 0    2662343  tt0111161   28767189.0
# 1    1847150  tt0068646  136381073.0
# 2    2638780  tt0468569  534987076.0
# 3    1265087  tt0071562   47834595.0
# 4     786180  tt0050083          NaN

# %%
# clean_df1.to_csv("IMDB_Cleaned_1.csv", encoding='utf-8', index=False)

# %%
clean_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   imdbRank      250 non-null    int64
#  1   Title         250 non-null    object
#  2   Year          250 non-null    int32
#  3   Rated         250 non-null    object
#  4   Released      250 non-null    object
#  5   Runtime_mins  250 non-null    int32
#  6   Genre         250 non-null    object
#  7   Director      250 non-null    object
#  8   Writer        250 non-null    object
#  9   Top_Billed    250 non-null    object
#  10  Language      250 non-null    object
#  11  Country       250 non-null    object
#  12  Awards        250 non-null    object
#  13  Metascore     250 non-null    float64
#  14  imdbRating    250 non-null    float64
#  15  imdbVotes     250 non-null    int32
#  16  imdbID        250 non-null    object
#  17  BoxOffice     220 non-null    float64
# dtypes: float64(3), int32(3), int64(1), object(11)
# memory usage: 32.4+ KB

# %%
clean_df1 = clean_df1.drop(columns=['Released'])
clean_df1.head()
# Out:
#    imdbRank                     Title  Year     Rated  Runtime_mins   Genre  \
# 0         1  The Shawshank Redemption  1994         R           142   Drama
# 1         2             The Godfather  1972         R           175   Crime
# 2         3           The Dark Knight  2008     PG-13           152  Action
# 3         4     The Godfather Part II  1974         R           202   Crime
# 4         5              12 Angry Men  1957  Approved            96   Crime
#
#                Director                                             Writer  \
# 0        Frank Darabont                       Stephen King, Frank Darabont
# 1  Francis Ford Coppola                   Mario Puzo, Francis Ford Coppola
# 2     Christopher Nolan  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3  Francis Ford Coppola                   Francis Ford Coppola, Mario Puzo
# 4          Sidney Lumet                                      Reginald Rose
#
#                                     Top_Billed Language        Country  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton  English  United States
# 1         Marlon Brando, Al Pacino, James Caan  English  United States
# 2  Christian Bale, Heath Ledger, Aaron Eckhart  English  United States
# 3     Al Pacino, Robert De Niro, Robert Duvall  English  United States
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam  English  United States
#
#                                               Awards  Metascore  imdbRating  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...       81.0         9.3
# 1       Won 3 Oscars. 32 wins & 30 nominations total      100.0         9.2
# 2     Won 2 Oscars. 160 wins & 163 nominations total       84.0         9.0
# 3       Won 6 Oscars. 17 wins & 21 nominations total       90.0         9.0
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...       96.0         9.0
#
#    imdbVotes     imdbID    BoxOffice
# 0    2662343  tt0111161   28767189.0
# 1    1847150  tt0068646  136381073.0
# 2    2638780  tt0468569  534987076.0
# 3    1265087  tt0071562   47834595.0
# 4     786180  tt0050083          NaN

# %%
# clean_df1.to_csv("IMDB_Cleaned_2.csv", encoding='utf-8', index=False)

# %%
clean_df1.loc[clean_df1.Language == "None"]
# Out:
#      imdbRank                       Title  Year   Rated  Runtime_mins  \
# 51         52                 City Lights  1931       G            87
# 185       186                 The General  1926  Passed            67
# 206       207  The Passion of Joan of Arc  1928  Passed           114
#
#          Genre                       Director  \
# 51      Comedy                Charles Chaplin
# 185     Action  Clyde Bruckman, Buster Keaton
# 206  Biography            Carl Theodor Dreyer
#
#                                          Writer  \
# 51   Charles Chaplin, Harry Carr, Harry Crocker
# 185  Buster Keaton, Clyde Bruckman, Al Boasberg
# 206         Joseph Delteil, Carl Theodor Dreyer
#
#                                            Top_Billed Language        Country  \
# 51   Charles Chaplin, Virginia Cherrill, Florence Lee     None  United States
# 185         Buster Keaton, Marion Mack, Glen Cavender     None  United States
# 206    Maria Falconetti, Eugene Silvain, André Berley     None         France
#
#                      Awards  Metascore  imdbRating  imdbVotes     imdbID  \
# 51    4 wins & 1 nomination       99.0         8.5     184997  tt0021749
# 185   2 wins & 1 nomination        0.0         8.2      92056  tt0017925
# 206  5 wins & 2 nominations        0.0         8.2      55266  tt0019254
#
#      BoxOffice
# 51     19181.0
# 185        NaN
# 206    21877.0

# %%
clean_df1['Language'] = clean_df1['Language'].str.replace("None", "Silent")

# %%
clean_df1.Rated.value_counts()
# Out:
# R            104
# G             48
# PG            39
# PG-13         34
# Not Rated     24
# X              1
# Name: Rated, dtype: int64

# %%
clean_df1.loc[clean_df1.Rated == "Unrated"]
# Out:
#     imdbRank                Title  Year    Rated  Runtime_mins  Genre  \
# 83        84  Requiem for a Dream  2000  Unrated           102  Drama
#
#             Director                              Writer  \
# 83  Darren Aronofsky  Hubert Selby Jr., Darren Aronofsky
#
#                                       Top_Billed Language        Country  \
# 83  Ellen Burstyn, Jared Leto, Jennifer Connelly  English  United States
#
#                                                Awards  Metascore  imdbRating  \
# 83  Nominated for 1 Oscar. 37 wins & 70 nomination...       68.0         8.3
#
#     imdbVotes     imdbID  BoxOffice
# 83     840283  tt0180093  3635482.0

# %%
clean_df1['Rated'] = clean_df1['Rated'].str.replace("Unrated", "R")

# %%
clean_df1.to_csv("IMDB_Cleaned_Final.csv", encoding='utf-8', index=False)

# %%
##added in csv files to this notebook from Garret's work above

# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine, inspect

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import countries csv
countries_path = "all_countries.csv"
countries_df = pd.read_csv(countries_path)
countries_df = countries_df.rename(columns = {"0":"country"})
countries_df
# Out:
#            country
# 0    United States
# 1      New Zealand
# 2            Italy
# 3          Germany
# 4            Japan
# 5           Brazil
# 6           France
# 7      South Korea
# 8   United Kingdom
# 9     West Germany
# 10           India
# 11         Lebanon
# 12         Denmark
# 13    Soviet Union
# 14          Canada
# 15            Iran
# 16          Mexico
# 17       Argentina
# 18          Sweden
# 19         Ireland
# 20           Spain
# 21       Australia
# 22          Turkey

# %%
#import genres csv
genres_path = "all_genres.csv"
genres_df = pd.read_csv(genres_path)
genres_df = genres_df.rename(columns = {"0":"genre"})
genres_df
# Out:
#         genre
# 0       Drama
# 1       Crime
# 2      Action
# 3   Biography
# 4   Adventure
# 5      Comedy
# 6   Animation
# 7      Horror
# 8     Western
# 9     Mystery
# 10  Film-Noir

# %%
#import languages csv
languages_path = "all_languages.csv"
languages_df = pd.read_csv(languages_path)
languages_df = languages_df.rename(columns = {"0":"language"})
languages_df
# Out:
#       language
# 0      English
# 1      Italian
# 2     Japanese
# 3   Portuguese
# 4       Korean
# 5       French
# 6       Silent
# 7       German
# 8        Hindi
# 9       Arabic
# 10      Danish
# 11     Russian
# 12     Persian
# 13     Spanish
# 14     Swedish
# 15     Bengali
# 16       Tamil
# 17     Turkish

# %%
#import ratings csv
ratings_path = "all_ratings.csv"
ratings_df = pd.read_csv(ratings_path)
ratings_df = ratings_df.rename(columns = {"0":"mpaa_rating"})
ratings_df
# Out:
#   mpaa_rating
# 0           R
# 1       PG-13
# 2           G
# 3          PG
# 4   Not Rated
# 5           X

# %%
#import imdb csv
imdb_path = "IMDB_Cleaned_Final.csv"
imdb_df = pd.read_csv(imdb_path)
imdb_df
# Out:
#      imdbRank                              Title  Year  Rated  Runtime_mins  \
# 0           1           The Shawshank Redemption  1994      R           142
# 1           2                      The Godfather  1972      R           175
# 2           3                    The Dark Knight  2008  PG-13           152
# 3           4              The Godfather Part II  1974      R           202
# 4           5                       12 Angry Men  1957      G            96
# ..        ...                                ...   ...    ...           ...
# 245       246  Everything Everywhere All at Once  2022      R           139
# 246       247                     The Iron Giant  1999     PG            86
# 247       248                           The Help  2011  PG-13           146
# 248       249                            Aladdin  1992      G            90
# 249       250                             Gandhi  1982     PG           191
#
#          Genre                    Director  \
# 0        Drama              Frank Darabont
# 1        Crime        Francis Ford Coppola
# 2       Action           Christopher Nolan
# 3        Crime        Francis Ford Coppola
# 4        Crime                Sidney Lumet
# ..         ...                         ...
# 245     Action  Dan Kwan, Daniel Scheinert
# 246  Animation                   Brad Bird
# 247      Drama                 Tate Taylor
# 248  Animation   Ron Clements, John Musker
# 249  Biography        Richard Attenborough
#
#                                                 Writer  \
# 0                         Stephen King, Frank Darabont
# 1                     Mario Puzo, Francis Ford Coppola
# 2    Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3                     Francis Ford Coppola, Mario Puzo
# 4                                        Reginald Rose
# ..                                                 ...
# 245                         Dan Kwan, Daniel Scheinert
# 246               Tim McCanlies, Brad Bird, Ted Hughes
# 247                      Tate Taylor, Kathryn Stockett
# 248             Ron Clements, John Musker, Ted Elliott
# 249                                        John Briley
#
#                                             Top_Billed Language  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton  English
# 1                 Marlon Brando, Al Pacino, James Caan  English
# 2          Christian Bale, Heath Ledger, Aaron Eckhart  English
# 3             Al Pacino, Robert De Niro, Robert Duvall  English
# 4              Henry Fonda, Lee J. Cobb, Martin Balsam  English
# ..                                                 ...      ...
# 245     Michelle Yeoh, Stephanie Hsu, Jamie Lee Curtis  English
# 246  Eli Marienthal, Harry Connick Jr., Jennifer An...  English
# 247           Viola Davis, Emma Stone, Octavia Spencer  English
# 248        Scott Weinger, Robin Williams, Linda Larkin  English
# 249      Ben Kingsley, John Gielgud, Rohini Hattangadi  English
#
#             Country                                             Awards  \
# 0     United States  Nominated for 7 Oscars. 21 wins & 43 nominatio...
# 1     United States       Won 3 Oscars. 32 wins & 30 nominations total
# 2     United States     Won 2 Oscars. 160 wins & 163 nominations total
# 3     United States       Won 6 Oscars. 17 wins & 21 nominations total
# 4     United States  Nominated for 3 Oscars. 17 wins & 13 nominatio...
# ..              ...                                                ...
# 245   United States                          54 wins & 121 nominations
# 246   United States    Won 1 BAFTA Award20 wins & 18 nominations total
# 247   United States       Won 1 Oscar. 79 wins & 121 nominations total
# 248   United States       Won 2 Oscars. 34 wins & 22 nominations total
# 249  United Kingdom       Won 8 Oscars. 35 wins & 21 nominations total
#
#      Metascore  imdbRating  imdbVotes     imdbID    BoxOffice
# 0         81.0         9.3    2662343  tt0111161   28767189.0
# 1        100.0         9.2    1847150  tt0068646  136381073.0
# 2         84.0         9.0    2638780  tt0468569  534987076.0
# 3         90.0         9.0    1265087  tt0071562   47834595.0
# 4         96.0         9.0     786180  tt0050083          NaN
# ..         ...         ...        ...        ...          ...
# 245       81.0         8.1     251736  tt6710474   70008593.0
# 246       85.0         8.1     198212  tt0129167   23315035.0
# 247       62.0         8.1     459753  tt1454029  169708112.0
# 248       86.0         8.0     420013  tt0103639  217350219.0
# 249       79.0         8.1     232139  tt0083987   52767889.0
#
# [250 rows x 17 columns]

# %%
# imdb_df["Genre"].apply(lambda x : genres_df.genre[genres_df.genre == x].index.tolist()[0])

# %%
# imdb_df["genre_id"] = imdb_df["Genre"].apply(lambda x : genres_df.genre[genres_df.genre == x].index.tolist()[0])
# imdb_df

# %%
# imdb_df["Genre"].apply(lambda x : genres_df.genre[genres_df.genre == x].index.tolist()[0])

# %%
#connect to Postgres

USERNAME = "postgres"
PASSWORD = "password"
URL = "localhost"
PORT = 5432
DATABASE = "movie_db"

connection_str = f"postgresql+psycopg2://{USERNAME}:{PASSWORD}@{URL}:{PORT}/{DATABASE}"
print(connection_str)

engine = create_engine(connection_str)
# Out:
# postgresql+psycopg2://postgres:password@localhost:5432/movie_db

# %%
# create the inspector and connect to the engine 
# get all tables
inspector_gadget = inspect(engine)

tables = inspector_gadget.get_table_names()
for table in tables:
    print(table)
    
    # get all columns in table
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column)
    print()
# Out:
# film_rating
# {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': "nextval('film_rating_id_seq'::regclass)", 'autoincrement': True, 'comment': None}
# {'name': 'mpaa_rating', 'type': VARCHAR(length=20), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'last_updated', 'type': TIMESTAMP(), 'nullable': False, 'default': 'LOCALTIMESTAMP', 'autoincrement': False, 'comment': None}
#
# movie_info
# {'name': 'id', 'type': VARCHAR(), 'nullable': False, 'default': "nextval('movie_info_id_seq'::regclass)", 'autoincrement': False, 'comment': None}
# {'name': 'title', 'type': VARCHAR(length=250), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'year', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'rating_id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'genre_id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'director', 'type': VARCHAR(length=300), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'box_office', 'type': DOUBLE_PRECISION(precision=53), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'runtime_mins', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'top_billed', 'type': VARCHAR(length=500), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'awards', 'type': VARCHAR(length=500), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'writer', 'type': VARCHAR(length=500), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'language_id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'country_id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'imdb_ratings', 'type': DOUBLE_PRECISION(precision=53), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'meta_score', 'type': DOUBLE_PRECISION(precision=53), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'imdb_rank', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'imdb_votes', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'last_updated', 'type': TIMESTAMP(), 'nullable': False, 'default': 'LOCALTIMESTAMP', 'autoincrement': False, 'comment': None}
#
# country
# {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': "nextval('country_id_seq'::regclass)", 'autoincrement': True, 'comment': None}
# {'name': 'country', 'type': VARCHAR(length=100), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'last_updated', 'type': TIMESTAMP(), 'nullable': False, 'default': 'LOCALTIMESTAMP', 'autoincrement': False, 'comment': None}
#
# genre
# {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': "nextval('genre_id_seq'::regclass)", 'autoincrement': True, 'comment': None}
# {'name': 'genre', 'type': VARCHAR(length=50), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'last_updated', 'type': TIMESTAMP(), 'nullable': False, 'default': 'LOCALTIMESTAMP', 'autoincrement': False, 'comment': None}
#
# language
# {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': "nextval('language_id_seq'::regclass)", 'autoincrement': True, 'comment': None}
# {'name': 'language', 'type': VARCHAR(length=100), 'nullable': False, 'default': None, 'autoincrement': False, 'comment': None}
# {'name': 'last_updated', 'type': TIMESTAMP(), 'nullable': False, 'default': 'LOCALTIMESTAMP', 'autoincrement': False, 'comment': None}

# %%
#add dataframes to SQL 
engine.execute("truncate table country restart identity cascade;") #fix issue of making duplicaties
countries_df.to_sql('country', engine, if_exists='append', index=False)
# Out:
# 23

# %%
engine.execute("truncate table genre restart identity cascade;")  #fix issue of making duplicates
engine.execute("truncate table language restart identity cascade;") 
engine.execute("truncate table film_rating restart identity cascade;") 
#add dataframes to SQL 
genres_df.to_sql('genre', engine, if_exists='append', index=False)
languages_df.to_sql('language', engine, if_exists='append', index=False)
ratings_df.to_sql('film_rating', engine, if_exists='append', index=False)
# Out:
# 6

# %%
##Added into postgres above -- below is creating indexes/ids to lookup tables and adding main table into postgres

# %%
imdb_df.head()
# Out:
#    imdbRank                     Title  Year  Rated  Runtime_mins   Genre  \
# 0         1  The Shawshank Redemption  1994      R           142   Drama
# 1         2             The Godfather  1972      R           175   Crime
# 2         3           The Dark Knight  2008  PG-13           152  Action
# 3         4     The Godfather Part II  1974      R           202   Crime
# 4         5              12 Angry Men  1957      G            96   Crime
#
#                Director                                             Writer  \
# 0        Frank Darabont                       Stephen King, Frank Darabont
# 1  Francis Ford Coppola                   Mario Puzo, Francis Ford Coppola
# 2     Christopher Nolan  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 3  Francis Ford Coppola                   Francis Ford Coppola, Mario Puzo
# 4          Sidney Lumet                                      Reginald Rose
#
#                                     Top_Billed Language        Country  \
# 0      Tim Robbins, Morgan Freeman, Bob Gunton  English  United States
# 1         Marlon Brando, Al Pacino, James Caan  English  United States
# 2  Christian Bale, Heath Ledger, Aaron Eckhart  English  United States
# 3     Al Pacino, Robert De Niro, Robert Duvall  English  United States
# 4      Henry Fonda, Lee J. Cobb, Martin Balsam  English  United States
#
#                                               Awards  Metascore  imdbRating  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...       81.0         9.3
# 1       Won 3 Oscars. 32 wins & 30 nominations total      100.0         9.2
# 2     Won 2 Oscars. 160 wins & 163 nominations total       84.0         9.0
# 3       Won 6 Oscars. 17 wins & 21 nominations total       90.0         9.0
# 4  Nominated for 3 Oscars. 17 wins & 13 nominatio...       96.0         9.0
#
#    imdbVotes     imdbID    BoxOffice
# 0    2662343  tt0111161   28767189.0
# 1    1847150  tt0068646  136381073.0
# 2    2638780  tt0468569  534987076.0
# 3    1265087  tt0071562   47834595.0
# 4     786180  tt0050083          NaN

# %%
#create ids for ratings table
rating2df = pd.read_sql("SELECT id, mpaa_rating FROM film_rating", engine)
rating2df.columns=["rating_id", "Rated"]
rating2df.head()
# Out:
#    rating_id      Rated
# 0          1          R
# 1          2      PG-13
# 2          3          G
# 3          4         PG
# 4          5  Not Rated

# %%
imdb_df = pd.merge(imdb_df, rating2df, on="Rated")
imdb_df.drop("Rated", axis=1, inplace=True)
imdb_df.head()
# Out:
#    imdbRank                     Title  Year  Runtime_mins      Genre  \
# 0         1  The Shawshank Redemption  1994           142      Drama
# 1         2             The Godfather  1972           175      Crime
# 2         4     The Godfather Part II  1974           202      Crime
# 3         6          Schindler's List  1993           195  Biography
# 4         8              Pulp Fiction  1994           154      Crime
#
#                Director                            Writer  \
# 0        Frank Darabont      Stephen King, Frank Darabont
# 1  Francis Ford Coppola  Mario Puzo, Francis Ford Coppola
# 2  Francis Ford Coppola  Francis Ford Coppola, Mario Puzo
# 3      Steven Spielberg  Thomas Keneally, Steven Zaillian
# 4     Quentin Tarantino    Quentin Tarantino, Roger Avary
#
#                                       Top_Billed Language        Country  \
# 0        Tim Robbins, Morgan Freeman, Bob Gunton  English  United States
# 1           Marlon Brando, Al Pacino, James Caan  English  United States
# 2       Al Pacino, Robert De Niro, Robert Duvall  English  United States
# 3       Liam Neeson, Ralph Fiennes, Ben Kingsley  English  United States
# 4  John Travolta, Uma Thurman, Samuel L. Jackson  English  United States
#
#                                               Awards  Metascore  imdbRating  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...       81.0         9.3
# 1       Won 3 Oscars. 32 wins & 30 nominations total      100.0         9.2
# 2       Won 6 Oscars. 17 wins & 21 nominations total       90.0         9.0
# 3       Won 7 Oscars. 91 wins & 49 nominations total       94.0         9.0
# 4        Won 1 Oscar. 70 wins & 75 nominations total       94.0         8.9
#
#    imdbVotes     imdbID    BoxOffice  rating_id
# 0    2662343  tt0111161   28767189.0          1
# 1    1847150  tt0068646  136381073.0          1
# 2    1265087  tt0071562   47834595.0          1
# 3    1349692  tt0108052   96898818.0          1
# 4    2040285  tt0110912  107928762.0          1

# %%
rating2df
# Out:
#    rating_id      Rated
# 0          1          R
# 1          2      PG-13
# 2          3          G
# 3          4         PG
# 4          5  Not Rated
# 5          6          X

# %%
#create ids for country table
country2df = pd.read_sql("SELECT id, country FROM country", engine)
country2df.columns=["country_id", "Country"]
country2df.head()
# Out:
#    country_id        Country
# 0           1  United States
# 1           2    New Zealand
# 2           3          Italy
# 3           4        Germany
# 4           5          Japan

# %%
imdb_df = pd.merge(imdb_df, country2df, on="Country")
imdb_df.drop("Country", axis=1, inplace=True)
imdb_df.head()
# Out:
#    imdbRank                     Title  Year  Runtime_mins      Genre  \
# 0         1  The Shawshank Redemption  1994           142      Drama
# 1         2             The Godfather  1972           175      Crime
# 2         4     The Godfather Part II  1974           202      Crime
# 3         6          Schindler's List  1993           195  Biography
# 4         8              Pulp Fiction  1994           154      Crime
#
#                Director                            Writer  \
# 0        Frank Darabont      Stephen King, Frank Darabont
# 1  Francis Ford Coppola  Mario Puzo, Francis Ford Coppola
# 2  Francis Ford Coppola  Francis Ford Coppola, Mario Puzo
# 3      Steven Spielberg  Thomas Keneally, Steven Zaillian
# 4     Quentin Tarantino    Quentin Tarantino, Roger Avary
#
#                                       Top_Billed Language  \
# 0        Tim Robbins, Morgan Freeman, Bob Gunton  English
# 1           Marlon Brando, Al Pacino, James Caan  English
# 2       Al Pacino, Robert De Niro, Robert Duvall  English
# 3       Liam Neeson, Ralph Fiennes, Ben Kingsley  English
# 4  John Travolta, Uma Thurman, Samuel L. Jackson  English
#
#                                               Awards  Metascore  imdbRating  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...       81.0         9.3
# 1       Won 3 Oscars. 32 wins & 30 nominations total      100.0         9.2
# 2       Won 6 Oscars. 17 wins & 21 nominations total       90.0         9.0
# 3       Won 7 Oscars. 91 wins & 49 nominations total       94.0         9.0
# 4        Won 1 Oscar. 70 wins & 75 nominations total       94.0         8.9
#
#    imdbVotes     imdbID    BoxOffice  rating_id  country_id
# 0    2662343  tt0111161   28767189.0          1           1
# 1    1847150  tt0068646  136381073.0          1           1
# 2    1265087  tt0071562   47834595.0          1           1
# 3    1349692  tt0108052   96898818.0          1           1
# 4    2040285  tt0110912  107928762.0          1           1

# %%
#create ids for genre table
genre2df = pd.read_sql("SELECT id, genre FROM genre", engine)
genre2df.columns=["genre_id", "Genre"]
genre2df.head()
# Out:
#    genre_id      Genre
# 0         1      Drama
# 1         2      Crime
# 2         3     Action
# 3         4  Biography
# 4         5  Adventure

# %%
imdb_df = pd.merge(imdb_df, genre2df, on="Genre")
imdb_df.drop("Genre", axis=1, inplace=True)
imdb_df.head()
# Out:
#    imdbRank                            Title  Year  Runtime_mins  \
# 0         1         The Shawshank Redemption  1994           142
# 1        18  One Flew Over the Cuckoo's Nest  1975           133
# 2        24              Saving Private Ryan  1998           169
# 3        42                         Whiplash  2014           106
# 4        53                   Apocalypse Now  1979           147
#
#                Director                                           Writer  \
# 0        Frank Darabont                     Stephen King, Frank Darabont
# 1          Milos Forman           Lawrence Hauben, Bo Goldman, Ken Kesey
# 2      Steven Spielberg                                     Robert Rodat
# 3       Damien Chazelle                                  Damien Chazelle
# 4  Francis Ford Coppola  John Milius, Francis Ford Coppola, Michael Herr
#
#                                           Top_Billed Language  \
# 0            Tim Robbins, Morgan Freeman, Bob Gunton  English
# 1  Jack Nicholson, Louise Fletcher, Michael Berryman  English
# 2                Tom Hanks, Matt Damon, Tom Sizemore  English
# 3        Miles Teller, J.K. Simmons, Melissa Benoist  English
# 4         Martin Sheen, Marlon Brando, Robert Duvall  English
#
#                                               Awards  Metascore  imdbRating  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...       81.0         9.3
# 1       Won 5 Oscars. 39 wins & 16 nominations total       84.0         8.7
# 2       Won 5 Oscars. 79 wins & 75 nominations total       91.0         8.6
# 3      Won 3 Oscars. 98 wins & 146 nominations total       89.0         8.5
# 4       Won 2 Oscars. 21 wins & 33 nominations total       94.0         8.5
#
#    imdbVotes     imdbID    BoxOffice  rating_id  country_id  genre_id
# 0    2662343  tt0111161   28767189.0          1           1         1
# 1    1004277  tt0073486  108981275.0          1           1         1
# 2    1385405  tt0120815  217049603.0          1           1         1
# 3     854378  tt2582802   13092000.0          1           1         1
# 4     666279  tt0078788   96041782.0          1           1         1

# %%
#create ids for language table
language2df = pd.read_sql("SELECT id, language FROM language", engine)
language2df.columns=["language_id", "Language"]
language2df.head()
# Out:
#    language_id    Language
# 0            1     English
# 1            2     Italian
# 2            3    Japanese
# 3            4  Portuguese
# 4            5      Korean

# %%
imdb_df = pd.merge(imdb_df, language2df, on="Language")
imdb_df.drop("Language", axis=1, inplace=True)
imdb_df.head()
# Out:
#    imdbRank                            Title  Year  Runtime_mins  \
# 0         1         The Shawshank Redemption  1994           142
# 1        18  One Flew Over the Cuckoo's Nest  1975           133
# 2        24              Saving Private Ryan  1998           169
# 3        42                         Whiplash  2014           106
# 4        53                   Apocalypse Now  1979           147
#
#                Director                                           Writer  \
# 0        Frank Darabont                     Stephen King, Frank Darabont
# 1          Milos Forman           Lawrence Hauben, Bo Goldman, Ken Kesey
# 2      Steven Spielberg                                     Robert Rodat
# 3       Damien Chazelle                                  Damien Chazelle
# 4  Francis Ford Coppola  John Milius, Francis Ford Coppola, Michael Herr
#
#                                           Top_Billed  \
# 0            Tim Robbins, Morgan Freeman, Bob Gunton
# 1  Jack Nicholson, Louise Fletcher, Michael Berryman
# 2                Tom Hanks, Matt Damon, Tom Sizemore
# 3        Miles Teller, J.K. Simmons, Melissa Benoist
# 4         Martin Sheen, Marlon Brando, Robert Duvall
#
#                                               Awards  Metascore  imdbRating  \
# 0  Nominated for 7 Oscars. 21 wins & 43 nominatio...       81.0         9.3
# 1       Won 5 Oscars. 39 wins & 16 nominations total       84.0         8.7
# 2       Won 5 Oscars. 79 wins & 75 nominations total       91.0         8.6
# 3      Won 3 Oscars. 98 wins & 146 nominations total       89.0         8.5
# 4       Won 2 Oscars. 21 wins & 33 nominations total       94.0         8.5
#
#    imdbVotes     imdbID    BoxOffice  rating_id  country_id  genre_id  \
# 0    2662343  tt0111161   28767189.0          1           1         1
# 1    1004277  tt0073486  108981275.0          1           1         1
# 2    1385405  tt0120815  217049603.0          1           1         1
# 3     854378  tt2582802   13092000.0          1           1         1
# 4     666279  tt0078788   96041782.0          1           1         1
#
#    language_id
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
#rename columns to match movie_info table in database
imdb_df = imdb_df.rename(columns = {"Title":"title", "Year": "year", "Director": "director", "Writer": "writer", "Top_Billed": "top_billed", "imdbRating": "imdb_ratings", "Awards": "awards", "Metascore":"meta_score", "BoxOffice": "box_office", "Runtime_mins": "runtime_mins", "imdbRank":"imdb_rank", "imdbVotes": "imdb_votes", "imdbID": "id"})
imdb_df
# Out:
#      imdb_rank                            title  year  runtime_mins  \
# 0            1         The Shawshank Redemption  1994           142
# 1           18  One Flew Over the Cuckoo's Nest  1975           133
# 2           24              Saving Private Ryan  1998           169
# 3           42                         Whiplash  2014           106
# 4           53                   Apocalypse Now  1979           147
# ..         ...                              ...   ...           ...
# 245         23                      City of God  2002           130
# 246        230                         Jai Bhim  2021           164
# 247        207       The Passion of Joan of Arc  1928           114
# 248        186                      The General  1926            67
# 249         52                      City Lights  1931            87
#
#                            director  \
# 0                    Frank Darabont
# 1                      Milos Forman
# 2                  Steven Spielberg
# 3                   Damien Chazelle
# 4              Francis Ford Coppola
# ..                              ...
# 245  Fernando Meirelles, Kátia Lund
# 246                   T.J. Gnanavel
# 247             Carl Theodor Dreyer
# 248   Clyde Bruckman, Buster Keaton
# 249                 Charles Chaplin
#
#                                               writer  \
# 0                       Stephen King, Frank Darabont
# 1             Lawrence Hauben, Bo Goldman, Ken Kesey
# 2                                       Robert Rodat
# 3                                    Damien Chazelle
# 4    John Milius, Francis Ford Coppola, Michael Herr
# ..                                               ...
# 245                    Paulo Lins, Bráulio Mantovani
# 246                    T.J. Gnanavel, Rajendra Sapre
# 247              Joseph Delteil, Carl Theodor Dreyer
# 248       Buster Keaton, Clyde Bruckman, Al Boasberg
# 249       Charles Chaplin, Harry Carr, Harry Crocker
#
#                                             top_billed  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton
# 1    Jack Nicholson, Louise Fletcher, Michael Berryman
# 2                  Tom Hanks, Matt Damon, Tom Sizemore
# 3          Miles Teller, J.K. Simmons, Melissa Benoist
# 4           Martin Sheen, Marlon Brando, Robert Duvall
# ..                                                 ...
# 245  Alexandre Rodrigues, Leandro Firmino, Matheus ...
# 246               Suriya, Lijo Mol Jose, Manikandan K.
# 247     Maria Falconetti, Eugene Silvain, André Berley
# 248          Buster Keaton, Marion Mack, Glen Cavender
# 249   Charles Chaplin, Virginia Cherrill, Florence Lee
#
#                                                 awards  meta_score  \
# 0    Nominated for 7 Oscars. 21 wins & 43 nominatio...        81.0
# 1         Won 5 Oscars. 39 wins & 16 nominations total        84.0
# 2         Won 5 Oscars. 79 wins & 75 nominations total        91.0
# 3        Won 3 Oscars. 98 wins & 146 nominations total        89.0
# 4         Won 2 Oscars. 21 wins & 33 nominations total        94.0
# ..                                                 ...         ...
# 245  Nominated for 4 Oscars. 74 wins & 50 nominatio...        79.0
# 246                            6 wins & 16 nominations         0.0
# 247                             5 wins & 2 nominations         0.0
# 248                              2 wins & 1 nomination         0.0
# 249                              4 wins & 1 nomination        99.0
#
#      imdb_ratings  imdb_votes          id   box_office  rating_id  country_id  \
# 0             9.3     2662343   tt0111161   28767189.0          1           1
# 1             8.7     1004277   tt0073486  108981275.0          1           1
# 2             8.6     1385405   tt0120815  217049603.0          1           1
# 3             8.5      854378   tt2582802   13092000.0          1           1
# 4             8.5      666279   tt0078788   96041782.0          1           1
# ..            ...         ...         ...          ...        ...         ...
# 245           8.6      755381   tt0317248    7564459.0          1           6
# 246           8.9      201710  tt15097216          NaN          1          11
# 247           8.2       55266   tt0019254      21877.0          3           7
# 248           8.2       92056   tt0017925          NaN          3           1
# 249           8.5      184997   tt0021749      19181.0          3           1
#
#      genre_id  language_id
# 0           1            1
# 1           1            1
# 2           1            1
# 3           1            1
# 4           1            1
# ..        ...          ...
# 245         2            4
# 246         2           17
# 247         4            7
# 248         3            7
# 249         6            7
#
# [250 rows x 17 columns]

# %%
#fill null values
imdb_df = imdb_df.fillna(0)
imdb_df
# Out:
#      imdb_rank                            title  year  runtime_mins  \
# 0            1         The Shawshank Redemption  1994           142
# 1           18  One Flew Over the Cuckoo's Nest  1975           133
# 2           24              Saving Private Ryan  1998           169
# 3           42                         Whiplash  2014           106
# 4           53                   Apocalypse Now  1979           147
# ..         ...                              ...   ...           ...
# 245         23                      City of God  2002           130
# 246        230                         Jai Bhim  2021           164
# 247        207       The Passion of Joan of Arc  1928           114
# 248        186                      The General  1926            67
# 249         52                      City Lights  1931            87
#
#                            director  \
# 0                    Frank Darabont
# 1                      Milos Forman
# 2                  Steven Spielberg
# 3                   Damien Chazelle
# 4              Francis Ford Coppola
# ..                              ...
# 245  Fernando Meirelles, Kátia Lund
# 246                   T.J. Gnanavel
# 247             Carl Theodor Dreyer
# 248   Clyde Bruckman, Buster Keaton
# 249                 Charles Chaplin
#
#                                               writer  \
# 0                       Stephen King, Frank Darabont
# 1             Lawrence Hauben, Bo Goldman, Ken Kesey
# 2                                       Robert Rodat
# 3                                    Damien Chazelle
# 4    John Milius, Francis Ford Coppola, Michael Herr
# ..                                               ...
# 245                    Paulo Lins, Bráulio Mantovani
# 246                    T.J. Gnanavel, Rajendra Sapre
# 247              Joseph Delteil, Carl Theodor Dreyer
# 248       Buster Keaton, Clyde Bruckman, Al Boasberg
# 249       Charles Chaplin, Harry Carr, Harry Crocker
#
#                                             top_billed  \
# 0              Tim Robbins, Morgan Freeman, Bob Gunton
# 1    Jack Nicholson, Louise Fletcher, Michael Berryman
# 2                  Tom Hanks, Matt Damon, Tom Sizemore
# 3          Miles Teller, J.K. Simmons, Melissa Benoist
# 4           Martin Sheen, Marlon Brando, Robert Duvall
# ..                                                 ...
# 245  Alexandre Rodrigues, Leandro Firmino, Matheus ...
# 246               Suriya, Lijo Mol Jose, Manikandan K.
# 247     Maria Falconetti, Eugene Silvain, André Berley
# 248          Buster Keaton, Marion Mack, Glen Cavender
# 249   Charles Chaplin, Virginia Cherrill, Florence Lee
#
#                                                 awards  meta_score  \
# 0    Nominated for 7 Oscars. 21 wins & 43 nominatio...        81.0
# 1         Won 5 Oscars. 39 wins & 16 nominations total        84.0
# 2         Won 5 Oscars. 79 wins & 75 nominations total        91.0
# 3        Won 3 Oscars. 98 wins & 146 nominations total        89.0
# 4         Won 2 Oscars. 21 wins & 33 nominations total        94.0
# ..                                                 ...         ...
# 245  Nominated for 4 Oscars. 74 wins & 50 nominatio...        79.0
# 246                            6 wins & 16 nominations         0.0
# 247                             5 wins & 2 nominations         0.0
# 248                              2 wins & 1 nomination         0.0
# 249                              4 wins & 1 nomination        99.0
#
#      imdb_ratings  imdb_votes          id   box_office  rating_id  country_id  \
# 0             9.3     2662343   tt0111161   28767189.0          1           1
# 1             8.7     1004277   tt0073486  108981275.0          1           1
# 2             8.6     1385405   tt0120815  217049603.0          1           1
# 3             8.5      854378   tt2582802   13092000.0          1           1
# 4             8.5      666279   tt0078788   96041782.0          1           1
# ..            ...         ...         ...          ...        ...         ...
# 245           8.6      755381   tt0317248    7564459.0          1           6
# 246           8.9      201710  tt15097216          0.0          1          11
# 247           8.2       55266   tt0019254      21877.0          3           7
# 248           8.2       92056   tt0017925          0.0          3           1
# 249           8.5      184997   tt0021749      19181.0          3           1
#
#      genre_id  language_id
# 0           1            1
# 1           1            1
# 2           1            1
# 3           1            1
# 4           1            1
# ..        ...          ...
# 245         2            4
# 246         2           17
# 247         4            7
# 248         3            7
# 249         6            7
#
# [250 rows x 17 columns]

# %%
engine.execute("truncate table movie_info restart identity cascade;") #fix issue of making duplicaties
imdb_df.to_sql('movie_info', engine, if_exists='append', index=False)
# Out:
# 250

# %%
#Number of movies in top 250 released by year
query = """
        SELECT
            mi.year,
            COUNT(*) AS Num_of_Movies
        FROM
            movie_info mi
        GROUP BY
            mi.year
        ORDER BY
            mi.year ASC;
        """

year_breakdown = pd.read_sql(query, engine)
year_breakdown.head()
# Out:
#    year  num_of_movies
# 0  1921              1
# 1  1924              1
# 2  1925              1
# 3  1926              1
# 4  1927              1

# %%
year_breakdown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           86 non-null     int64
#  1   num_of_movies  86 non-null     int64
# dtypes: int64(2)
# memory usage: 1.5 KB

# %%
year_breakdown.year.value_counts()
# Out:
# 1921    1
# 1991    1
# 1999    1
# 1998    1
# 1997    1
#        ..
# 1962    1
# 1961    1
# 1960    1
# 1959    1
# 2022    1
# Name: year, Length: 86, dtype: int64

# %%
#Line chart of movies in top 250 by year
x = year_breakdown.year
y = year_breakdown.num_of_movies
  
plt.plot(x, y)
plt.xlabel("Year")
plt.ylabel("Number of Movies")
plt.title("Movies by Year")
plt.show()

# %%
#Number of movies in top 250 by genre
query = """
        SELECT
            g.genre,
            COUNT(*) AS Num_of_Movies
        FROM
            movie_info mi
            JOIN genre g ON mi.genre_id = g.id
        GROUP BY
            g.genre
            ORDER BY
            Num_of_Movies DESC;
        """

genre_breakdown = pd.read_sql(query, engine)
genre_breakdown
# Out:
#         genre  num_of_movies
# 0       Drama             68
# 1      Action             46
# 2       Crime             35
# 3   Biography             23
# 4      Comedy             23
# 5   Animation             23
# 6   Adventure             21
# 7     Mystery              4
# 8      Horror              4
# 9     Western              2
# 10  Film-Noir              1

# %%
#Pie Chart
pies = genre_breakdown.genre
pie_votes = genre_breakdown.num_of_movies
# for customization
colors = ["yellow", "green", "lightblue", "orange", "red",
          "purple", "pink", "yellowgreen", "lightskyblue", "lightcoral", "seagreen"]
# explode = (.05, .05, .05, .05, .05, .05, .05, .05, .05, .05, .05)
# step 2, init the plot
fig = plt.figure(figsize=(20,12))
plt.pie(pie_votes, labels=pies, colors=colors, autopct="%1.1f%%", pctdistance=.85, shadow=True, startangle=140)
# step 2.5, draw a circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)
# step 3 - customization
plt.title("Donut Chart of Movie Genres\n", fontweight="bold")
plt.axis("equal")
# step 4 - show the pie
plt.show()

# %%
#Number of movies in top 250 by Country
query = """
        SELECT
            c.country,
            COUNT(*) AS Num_of_Movies
        FROM
            movie_info mi
            JOIN country c ON mi.country_id = c.id
        GROUP BY
            c.country
            ORDER BY
            Num_of_Movies ASC;
        """

country_breakdown = pd.read_sql(query, engine)
country_breakdown.head()
# Out:
#         country  num_of_movies
# 0  West Germany              1
# 1       Lebanon              1
# 2        Brazil              1
# 3       Denmark              1
# 4         Spain              1

# %%
# step 1 - get the data
x = country_breakdown.country
y = country_breakdown.num_of_movies

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.barh(x, y, color="seagreen")

# step 3 - customization
plt.ylabel("Country", fontname = "Helvetica", fontsize=16)
plt.xlabel("Number of Movies", fontname = "Helvetica", fontsize=16)
plt.title("Movie Count by Country", fontsize=24, fontweight="bold", fontname = "Helvetica")
# plt.xticks(fontsize=14, rotation=0)

plt.grid(axis="x", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
#number of movies in top 250 by language
query = """
        SELECT
            l.language,
            COUNT(*) AS Num_of_Movies
        FROM
            movie_info mi
            JOIN language l ON mi.country_id = l.id
        GROUP BY
            l.language
            ORDER BY
            Num_of_Movies ASC;
        """

language_breakdown = pd.read_sql(query, engine)
language_breakdown.head()
# Out:
#   language  num_of_movies
# 0  Persian              1
# 1  Swedish              1
# 2   French              1
# 3  Russian              1
# 4   Arabic              1

# %%
#step 1 - get the data
x = language_breakdown.language
y = language_breakdown.num_of_movies

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.barh(x, y, color="seagreen")

# step 3 - customization
plt.ylabel("Language", fontname = "Helvetica", fontsize=16)
plt.xlabel("Number of Movies", fontname = "Helvetica", fontsize=16)
plt.title("Movie Count by Language", fontsize=24, fontweight="bold", fontname = "Helvetica")

plt.grid(axis="x", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
#Number of movies in top 250 by Motion Picture Association of America Rating
query = """
        SELECT
            fr.mpaa_rating,
            COUNT(*) AS Num_of_Movies
        FROM
            movie_info mi
            JOIN film_rating fr ON mi.rating_id = fr.id
        GROUP BY
            fr.mpaa_rating
            ORDER BY
            Num_of_Movies DESC;
        """

rating_breakdown = pd.read_sql(query, engine)
rating_breakdown
# Out:
#   mpaa_rating  num_of_movies
# 0           R            104
# 1           G             48
# 2          PG             39
# 3       PG-13             34
# 4   Not Rated             24
# 5           X              1

# %%
pies = rating_breakdown.mpaa_rating
pie_votes = rating_breakdown.num_of_movies
# for customization
colors = ["yellow", "green", "lightblue", "orange", "purple", "pink"]

# step 2, init the plot
fig = plt.figure(figsize=(12,8))
plt.pie(pie_votes, labels=pies, colors=colors, explode=explode, autopct="%1.1f%%", pctdistance=.85, shadow=True, startangle=140)
# step 2.5, draw a circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# step 3 - customization
plt.title("Donut Chart of MPAA Ratings\n", fontweight="bold")
plt.axis("equal")

# step 4 - show the pie
plt.show()

# %%
#Number of movies in top 250 by directors
query = """
        SELECT
            mi.director,
            COUNT(*) AS Num_of_Movies
        FROM
            movie_info mi
        GROUP BY
            mi.director
            ORDER BY
            Num_of_Movies DESC;
        """

director_breakdown = pd.read_sql(query, engine)
director_breakdown.head()
# Out:
#             director  num_of_movies
# 0    Martin Scorsese              7
# 1     Akira Kurosawa              7
# 2   Steven Spielberg              7
# 3  Christopher Nolan              7
# 4    Stanley Kubrick              7

# %%
#Movies in top 250 runtime length by genre
query = """
        SELECT
            g.genre,
            mi.runtime_mins
        FROM
            movie_info mi
            JOIN genre g ON mi.genre_id = g.id
"""
genre2df= pd.read_sql(query, engine)
genre2df.head()
# Out:
#    genre  runtime_mins
# 0  Drama           142
# 1  Drama           133
# 2  Drama           169
# 3  Drama           106
# 4  Drama           147

# %%
#Violin Plot 
plt.figure(figsize=(10,6))
sns.violinplot(data=genre2df, x="genre", y="runtime_mins")
plt.title("Violin Plot of Genre & Runtime", fontsize=22, fontweight="bold", fontname = "Helvetica" )
plt.show()
